# %%
import pandas as pd

# %%
sales_df = pd.read_csv('./CSV/sales.csv')
stock_df = pd.read_csv('./CSV/StockDetails.csv')

# %%
sales_df.shape, stock_df.shape
# Out:
# ((9495, 8), (1703, 2))

# %%
# datatypes
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9495 entries, 0 to 9494
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   InvoiceNo    9495 non-null   object
#  1   StockCode    9495 non-null   object
#  2   Description  9495 non-null   object
#  3   Quantity     9495 non-null   int64
#  4   InvoiceDate  9495 non-null   object
#  5   UnitPrice    9495 non-null   float64
#  6   CustomerID   9495 non-null   int64
#  7   Country      9495 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 593.6+ KB

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1703 entries, 0 to 1702
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   StockCode    1703 non-null   object
#  1   Description  1703 non-null   object
# dtypes: object(2)
# memory usage: 26.7+ KB

# %%
#missing values (na)
stock_df_na = stock_df[stock_df.isna().any(axis=1)]
stock_df_na
# Out:
# Empty DataFrame
# Columns: [StockCode, Description]
# Index: []

# %%
sales_df_na = sales_df[sales_df.isna().any(axis=1)]
sales_df_na
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
#missing values (null)
stock_df_null = stock_df[stock_df.isnull().any(axis=1)]
stock_df_null
# Out:
# Empty DataFrame
# Columns: [StockCode, Description]
# Index: []

# %%
sales_df_null = sales_df[sales_df.isnull().any(axis=1)]
sales_df_null
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
#duplicates
stock_df_dpl= stock_df[stock_df.duplicated(keep=False)]
stock_df_dpl
# Out:
# Empty DataFrame
# Columns: [StockCode, Description]
# Index: []

# %%
sales_df_dpl= sales_df[sales_df.duplicated(keep=False)]
sales_df_dpl
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 270     538174     22326  ROUND SNACK BOXES SET OF4 WOODLAND         12
# 292     538174     22326  ROUND SNACK BOXES SET OF4 WOODLAND         12
# 1131    542106     20676                   RED RETROSPOT BOWL        24
# 1132    542106     20676                   RED RETROSPOT BOWL        24
# 3228    553731     23208        LUNCH BAG VINTAGE LEAF DESIGN        10
# 3232    553731     23208        LUNCH BAG VINTAGE LEAF DESIGN        10
# 3625    555162     22704                     WRAP RED APPLES         25
# 3626    555162     22704                     WRAP RED APPLES         25
# 3714    555383     21828               EIGHT PIECE SNAKE  SET         2
# 3736    555383     22668                    PINK BABY BUNTING         5
# 3744    555383     21828               EIGHT PIECE SNAKE  SET         2
# 3748    555383     22668                    PINK BABY BUNTING         5
# ...

# %%
sales_df['InvoiceDate']= pd.to_datetime(sales_df['InvoiceDate'], format='%d-%m-%Y %H:%M')
sales_df
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1       536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 2       536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 3       536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 4       536527     22244           3 HOOK HANGER MAGIC GARDEN        12
# ...        ...       ...                                  ...       ...
# 9490    581578     22993         SET OF 4 PANTRY JELLY MOULDS        12
# 9491    581578     22907     PACK OF 20 NAPKINS PANTRY DESIGN        12
# 9492    581578     22908        PACK OF 20 NAPKINS RED APPLES        12
# 9493    581578     23215     JINGLE BELL HEART ANTIQUE SILVER        12
# 9494    581578     22736          RIBBON REEL MAKING SNOWMEN         10
#
#              InvoiceDate  UnitPrice  CustomerID  Country
# ...

# %%
sales_df['date'] = sales_df['InvoiceDate'].dt.date
sales_df['month']= sales_df['InvoiceDate'].dt.month
sales_df['hour_of_trans']= sales_df['InvoiceDate'].dt.hour

# %%
sales_df['TotalPrice']=sales_df['Quantity']*sales_df['UnitPrice']

# %%
sales_df
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1       536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 2       536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 3       536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 4       536527     22244           3 HOOK HANGER MAGIC GARDEN        12
# ...        ...       ...                                  ...       ...
# 9490    581578     22993         SET OF 4 PANTRY JELLY MOULDS        12
# 9491    581578     22907     PACK OF 20 NAPKINS PANTRY DESIGN        12
# 9492    581578     22908        PACK OF 20 NAPKINS RED APPLES        12
# 9493    581578     23215     JINGLE BELL HEART ANTIQUE SILVER        12
# 9494    581578     22736          RIBBON REEL MAKING SNOWMEN         10
#
#              InvoiceDate  UnitPrice  CustomerID  Country        date  month  \
# ...

# %%
sales_df_sorted =sales_df.sort_values('Quantity', ascending=False)
sales_df_sorted.head(3)
# Out:
#      InvoiceNo StockCode                   Description  Quantity  \
# 3131    552978     15036     ASSORTED COLOURS SILK FAN       600
# 7032    570082     23379  PACK OF 12 RED APPLE TISSUES       432
# 4064    557055     15036     ASSORTED COLOURS SILK FAN       300
#
#              InvoiceDate  UnitPrice  CustomerID  Country        date  month  \
# 3131 2011-05-12 14:46:00       0.65       12590  Germany  2011-05-12      5
# 7032 2011-10-07 11:19:00       0.32       12524  Germany  2011-10-07     10
# 4064 2011-06-16 14:45:00       0.83       12621  Germany  2011-06-16      6
#
#       hour_of_trans  TotalPrice
# 3131             14      390.00
# 7032             11      138.24
# 4064             14      249.00

# %%
sales_df[sales_df['InvoiceNo']=='C539866']
# Out:
#     InvoiceNo StockCode                         Description  Quantity  \
# 488   C539866     22300        COFFEE MUG DOG + BALL DESIGN        -3
# 489   C539866     22634      CHILDS BREAKFAST SET SPACEBOY         -4
# 490   C539866     22636  CHILDS BREAKFAST SET CIRCUS PARADE        -2
#
#             InvoiceDate  UnitPrice  CustomerID  Country        date  month  \
# 488 2010-12-23 10:20:00       2.55       12427  Germany  2010-12-23     12
# 489 2010-12-23 10:20:00       8.50       12427  Germany  2010-12-23     12
# 490 2010-12-23 10:20:00       7.65       12427  Germany  2010-12-23     12
#
#      hour_of_trans  TotalPrice
# 488             10       -7.65
# 489             10      -34.00
# 490             10      -15.30

# %%
unique=sales_df['CustomerID'].unique()

# %%
avg_quantity_per_customer = sales_df.groupby(['CustomerID','InvoiceNo'])['Quantity'].sum().mean()
avg_quantity_per_customer
# Out:
# np.float64(194.77280265339968)

# %%
avg_quantity_per_invoice = sales_df.groupby(['CustomerID','InvoiceNo'])['Quantity'].mean()
avg_quantity_per_invoice
# Out:
# CustomerID  InvoiceNo
# 12426       554985        8.600000
# 12427       536861        7.900000
#             570452        7.600000
#             577135       56.666667
#             C539866      -3.000000
#                            ...
# 13816       C576229      -3.000000
# 13817       539946        7.000000
#             575713        9.866667
# 14335       565430        8.095238
#             578273        1.857143
# Name: Quantity, Length: 603, dtype: float64

# %%
quantity_sum = sales_df.groupby(['CustomerID','InvoiceNo'])['Quantity'].sum()
quantity_sum.reset_index()
# Out:
#      CustomerID InvoiceNo  Quantity
# 0         12426    554985       258
# 1         12427    536861        79
# 2         12427    570452       114
# 3         12427    577135       340
# 4         12427   C539866        -9
# ..          ...       ...       ...
# 598       13816   C576229        -3
# 599       13817    539946        63
# 600       13817    575713       148
# 601       14335    565430       340
# 602       14335    578273        39
#
# [603 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
stock_df.head(2)
# Out:
#   StockCode                          Description
# 0     22809              SET OF 6 T-LIGHTS SANTA
# 1     84347  ROTATING SILVER ANGELS T-LIGHT HLDR

# %%
sales_df_sorted_by_qty_10= sales_df.sort_values('Quantity', ascending=False).head(10)
sales_df_sorted_by_qty_10
# Out:
#      InvoiceNo StockCode                         Description  Quantity  \
# 3131    552978     15036           ASSORTED COLOURS SILK FAN       600
# 7032    570082     23379        PACK OF 12 RED APPLE TISSUES       432
# 4064    557055     15036           ASSORTED COLOURS SILK FAN       300
# 2712    550625     22893      MINI CAKE STAND T-LIGHT HOLDER       288
# 8682    577135     84598       BOYS ALPHABET IRON ON PATCHES       288
# 1624    544281     22585           PACK OF 6 BIRDY GIFT TAGS       288
# 4094    557466     84568     GIRLS ALPHABET IRON ON PATCHES        288
# 6972    569893     16045          POPART WOODEN PENCILS ASST       200
# 1694    544933     10135        COLOURING PENCILS BROWN TUBE       200
# 2693    550620     84945  MULTI COLOUR SILVER T-LIGHT HOLDER       192
#
#              InvoiceDate  UnitPrice  CustomerID  Country        date  month  \
# 3131 2011-05-12 14:46:00       0.65       12590  Germany  2011-05-12      5
# ...

# %%
sns.set_theme(style="darkgrid")

sns.barplot(data=sales_df_sorted_by_qty_10,  x='Description',y='Quantity', hue='Description', palette='pastel')
plt.xticks(rotation=45)
plt.xlabel('Items')
plt.ylabel('Quantity')
plt.show()

# %%
sales_df_sorted_by_hr = sales_df.sort_values('hour_of_trans', ascending=True)
sales_df_sorted_by_hr
# Out:
#      InvoiceNo StockCode                         Description  Quantity  \
# 8580    576893     84077   WORLD WAR 2 GLIDERS ASSTD DESIGNS        48
# 8581    576893     21917     SET 12 KIDS  WHITE CHALK STICKS        24
# 8582    576893     21156           RETROSPOT CHILDRENS APRON         8
# 8583    576893     22620         4 TRADITIONAL SPINNING TOPS        12
# 8584    576893     22549                    PICTURE DOMINOES        12
# ...        ...       ...                                 ...       ...
# 37      536840     21977  PACK OF 60 PINK PAISLEY CAKE CASES        24
# 38      536840     84991         60 TEATIME FAIRY CAKE CASES        24
# 31      536840     22962               JAM JAR WITH PINK LID        12
# 40      536840      POST                             POSTAGE         1
# 6982   C569973     22328  ROUND SNACK BOXES SET OF 4 FRUITS         -3
#
#              InvoiceDate  UnitPrice  CustomerID  Country        date  month  \
# ...

# %%
sales_df_sorted_by_hr = sales_df.sort_values('hour_of_trans', ascending=True)
sales_hrs = sales_df_sorted_by_hr.groupby('hour_of_trans')['Quantity'].sum()
sales_hrs = sales_hrs.reset_index()

# %%
sales_hrs
# Out:
#     hour_of_trans  Quantity
# 0               8      4696
# 1               9     14730
# 2              10     12703
# 3              11     12071
# 4              12     19870
# 5              13     17312
# 6              14     19425
# 7              15     12849
# 8              16      1529
# 9              17      2098
# 10             18       168
# 11             19        -3

# %%
sns.lineplot(data=sales_hrs, x='hour_of_trans', y='Quantity')
plt.show()

# %%
sales_df
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1       536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 2       536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 3       536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 4       536527     22244           3 HOOK HANGER MAGIC GARDEN        12
# ...        ...       ...                                  ...       ...
# 9490    581578     22993         SET OF 4 PANTRY JELLY MOULDS        12
# 9491    581578     22907     PACK OF 20 NAPKINS PANTRY DESIGN        12
# 9492    581578     22908        PACK OF 20 NAPKINS RED APPLES        12
# 9493    581578     23215     JINGLE BELL HEART ANTIQUE SILVER        12
# 9494    581578     22736          RIBBON REEL MAKING SNOWMEN         10
#
#              InvoiceDate  UnitPrice  CustomerID  Country        date  month  \
# ...

# %%
# top consumers by revenue
top_customers_sum = sales_df.groupby('CustomerID')['TotalPrice'].sum()
top_customers_sum.reset_index()
top_customers_5 = top_customers_sum.reset_index().sort_values('TotalPrice', ascending=False).head(5)

top_customers_5
# Out:
#     CustomerID  TotalPrice
# 3        12471    18740.92
# 53       12621    13612.07
# 9        12477    13117.01
# 42       12590     9861.38
# 80       12709     9294.10

# %%
labels = [f"Customer:{customer}" for customer in top_customers_5.CustomerID]

plt.pie(top_customers_5.TotalPrice, labels=labels, autopct='%1.1f%%')
plt.show()

# %%
sales_df
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1       536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 2       536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 3       536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 4       536527     22244           3 HOOK HANGER MAGIC GARDEN        12
# ...        ...       ...                                  ...       ...
# 9490    581578     22993         SET OF 4 PANTRY JELLY MOULDS        12
# 9491    581578     22907     PACK OF 20 NAPKINS PANTRY DESIGN        12
# 9492    581578     22908        PACK OF 20 NAPKINS RED APPLES        12
# 9493    581578     23215     JINGLE BELL HEART ANTIQUE SILVER        12
# 9494    581578     22736          RIBBON REEL MAKING SNOWMEN         10
#
#              InvoiceDate  UnitPrice  CustomerID  Country        date  month  \
# ...

# %%
sales_df_total_price_monthly = sales_df.groupby('month')['TotalPrice'].sum()
sales_df_total_price_monthly_reset = sales_df_total_price_monthly.reset_index()

# %%
sns.lineplot(data=sales_df_total_price_monthly_reset, x='month', y='TotalPrice')
plt.show()

# %%
sales_grp_top5_index=sales_df.groupby(['InvoiceNo'])['TotalPrice'].sum().reset_index().sort_values('TotalPrice', ascending=False).head(5).InvoiceNo
sales_grp_top5_index
# Out:
# 151    552978
# 271    564856
# 69     543737
# 449    581179
# 122    550137
# Name: InvoiceNo, dtype: object

# %%
sales_df_filtered = sales_df[sales_df['InvoiceNo'].isin(sales_grp_top5_index)]

sales_df_filtered
# Out:
#      InvoiceNo StockCode                         Description  Quantity  \
# 1531    543737     21484         CHICK GREY HOT WATER BOTTLE         8
# 1532    543737     21441           BLUE BIRDHOUSE DECORATION        12
# 1533    543737     21523  DOORMAT FANCY FONT HOME SWEET HOME         8
# 1534    543737     22365           DOORMAT RESPECTABLE HOUSE         8
# 1535    543737     22366                    DOORMAT AIRMAIL          8
# ...        ...       ...                                 ...       ...
# 9323    581179     23576        SNACK TRAY RED VINTAGE DOILY         8
# 9324    581179     23579            SNACK TRAY I LOVE LONDON         8
# 9325    581179     23580           SNACK TRAY HAPPY FOREST           8
# 9326    581179     23084                  RABBIT NIGHT LIGHT        24
# 9327    581179      POST                             POSTAGE         1
#
#              InvoiceDate  UnitPrice  CustomerID  Country        date  month  \
# ...

# %%
pt = sales_df_filtered.pivot_table(index='InvoiceNo', columns='Description', values='TotalPrice', fill_value=0)

pt
# Out:
# Description   DOLLY GIRL BEAKER   SET 2 TEA TOWELS I LOVE LONDON   \
# InvoiceNo
# 543737                      0.0                              17.7
# 550137                      0.0                               0.0
# 552978                      0.0                              70.8
# 564856                      0.0                               0.0
# 581179                     15.0                               0.0
#
# Description  3 HOOK HANGER MAGIC GARDEN  5 HOOK HANGER RED MAGIC TOADSTOOL  \
# InvoiceNo
# 543737                             70.2                               19.8
# 550137                             70.2                               39.6
# 552978                              0.0                               39.6
# 564856                            158.4                                0.0
# 581179                              0.0                                0.0
#
# Description  ALARM CLOCK BAKELIKE PINK  APRON APPLE DELIGHT  \
# InvoiceNo
# ...

# %%
pt.plot(kind='bar', stacked=True, figsize=(12, 6),
    colormap='tab20'  # You can try 'Set3', 'viridis', etc.
)
plt.title('Top 5 Invoices by Revenue with Item Contributions')
plt.xlabel('Invoice Number')
plt.ylabel('Revenue')
plt.legend(title='Item Description', bbox_to_anchor=(1, 1), loc='upper left')
#plt.tight_layout()
plt.show()

# %%
sales_df
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1       536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 2       536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 3       536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 4       536527     22244           3 HOOK HANGER MAGIC GARDEN        12
# ...        ...       ...                                  ...       ...
# 9490    581578     22993         SET OF 4 PANTRY JELLY MOULDS        12
# 9491    581578     22907     PACK OF 20 NAPKINS PANTRY DESIGN        12
# 9492    581578     22908        PACK OF 20 NAPKINS RED APPLES        12
# 9493    581578     23215     JINGLE BELL HEART ANTIQUE SILVER        12
# 9494    581578     22736          RIBBON REEL MAKING SNOWMEN         10
#
#              InvoiceDate  UnitPrice  CustomerID  Country        date  month  \
# ...

# %%
product_highest_revenue = sales_df.groupby('Description')['TotalPrice'].sum().reset_index().sort_values('TotalPrice', ascending=False)

product_highest_revenue
# Out:
#                               Description  TotalPrice
# 1084                              POSTAGE    20821.00
# 1176             REGENCY CAKESTAND 3 TIER     8257.35
# 1237  ROUND SNACK BOXES SET OF4 WOODLAND      3554.70
# 1235   ROUND SNACK BOXES SET OF 4 FRUITS      1949.95
# 1463                  SPACEBOY LUNCH BOX      1629.45
# ...                                   ...         ...
# 632         GROW YOUR OWN PLANT IN A CAN        -3.75
# 1537         TRAVEL CARD WALLET KEEP CALM       -8.40
# 172               BLUE PADDED SOFT MOBILE      -12.75
# 1551          TRIPLE PHOTO FRAME CORNICE       -19.90
# 1297      SET OF 3 BABUSHKA STACKING TINS      -25.50
#
# [1703 rows x 2 columns]

# %%
sales_df
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1       536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 2       536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 3       536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 4       536527     22244           3 HOOK HANGER MAGIC GARDEN        12
# ...        ...       ...                                  ...       ...
# 9490    581578     22993         SET OF 4 PANTRY JELLY MOULDS        12
# 9491    581578     22907     PACK OF 20 NAPKINS PANTRY DESIGN        12
# 9492    581578     22908        PACK OF 20 NAPKINS RED APPLES        12
# 9493    581578     23215     JINGLE BELL HEART ANTIQUE SILVER        12
# 9494    581578     22736          RIBBON REEL MAKING SNOWMEN         10
#
#              InvoiceDate  UnitPrice  CustomerID  Country        date  month  \
# ...

# %%
avg_order_Val_per_inv = sales_df.groupby('InvoiceNo')['TotalPrice'].mean().reset_index()
avg_order_Val_per_inv
# Out:
#     InvoiceNo  TotalPrice
# 0      536527   17.432000
# 1      536840   14.122727
# 2      536861   30.350000
# 3      536967   38.250000
# 4      536983   19.503333
# ..        ...         ...
# 598   C580313   -5.834000
# 599   C580714   -7.450000
# 600   C580740  -17.500000
# 601   C580989   -1.650000
# 602   C581409   -7.596154
#
# [603 rows x 2 columns]

# %%
sales_df
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1       536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 2       536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 3       536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 4       536527     22244           3 HOOK HANGER MAGIC GARDEN        12
# ...        ...       ...                                  ...       ...
# 9490    581578     22993         SET OF 4 PANTRY JELLY MOULDS        12
# 9491    581578     22907     PACK OF 20 NAPKINS PANTRY DESIGN        12
# 9492    581578     22908        PACK OF 20 NAPKINS RED APPLES        12
# 9493    581578     23215     JINGLE BELL HEART ANTIQUE SILVER        12
# 9494    581578     22736          RIBBON REEL MAKING SNOWMEN         10
#
#              InvoiceDate  UnitPrice  CustomerID  Country        date  month  \
# ...

# %%
s_df=sales_df.groupby('CustomerID')['InvoiceNo'].count().reset_index().sort_values('InvoiceNo', ascending=False).head(1)
s_df
# Out:
#    CustomerID  InvoiceNo
# 3       12471        531

# %%
products = stock_df['StockCode'].unique()
# Out:
# array(['22809', '84347', '84945', ..., '23562', '22633', '22081'],
#       shape=(1671,), dtype=object)

# %%
missing=sales_df[~sales_df['StockCode'].isin(products)]
missing
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, date, month, hour_of_trans, TotalPrice]
# Index: []

# %%
products2 = sales_df['StockCode'].unique()
products2
# Out:
# array(['22809', '84347', '84945', ..., '23562', '22633', '22081'],
#       shape=(1671,), dtype=object)
